# %% [markdown]
# # Similarity
#
# ---
#
# <img src="https://raw.githubusercontent.com/jhyun0919/EnergyData_jhyun/master/docs/images/bluprint_similarity.jpg" alt="Drawing" style="width: 800px;"/>
#
# ## Abstract
#
# * blah blah

# %% [markdown]
# ---
# # 01. Build Similarity Model(Matrix)

# %%
from utils import GlobalParameter
from utils import FileIO
from utils import Similarity
import os
import pandas as pd

# %%
model, path = Similarity.Build.similarity_model(time_interval=GlobalParameter.TimeInterval, 
                                  refined_type=GlobalParameter.FullyPreprocessedPath)
# Out:
# Build Similarity Model
# calculate covariance
# calculate cosine_similarity
# calculate euclidean_distance
# calculate manhattan_distance
# calculate gradient_similarity
# calculate reversed_gradient_similarity

# %% [markdown]
# ---
# ### 01-00. File list

# %%
model['file_list']
# Out:
# array([ '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_HA10_VM_EP_KV_K.bin',
#        '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_HA10_VM_KV_K.bin',
#        '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_HA10_VM_KV_KAM.bin',
#        '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_HA11_VM_EP_KV_K.bin',
#        '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_HA11_VM_KV_K.bin',
#        '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_HA11_VM_KV_KAM.bin',
#        '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_KIINT_KV_KAM.bin',
#        '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/VTT_GW1_KIINT_KV_KO_KAM.bin',
# ...

# %% [markdown]
# ---
# ### 01-01. Cosine Similarity
#
# * blah blah about cosine similarity

# %%
model['cosine_similarity']
# Out:
# array([[  1.20011145e-06,   4.64656165e-02,   1.87699950e+00,
#           8.11008196e-02,   8.51220035e-02,   1.50251707e+00,
#           2.20486843e+00,   2.09883902e+00,   5.03661729e-01,
#           2.60972655e+00,   5.73118707e-01,   4.52012166e-01,
#           2.46423454e+00,   3.41036546e-01,   8.70315493e-02,
#           2.60633105e+00],
#        [  4.64656165e-02,   2.84370155e-05,   1.87296738e+00,
#           1.26049931e-01,   1.04897210e-01,   1.50981159e+00,
#           2.19333523e+00,   2.09156566e+00,   5.03740055e-01,
#           2.60972655e+00,   6.09692822e-01,   3.89283912e-01,
#           2.46647182e+00,   3.81530102e-01,   7.32197615e-02,
#           2.60636356e+00],
#        [  1.87699950e+00,   1.87296738e+00,   7.36829092e-05,
#           1.90188137e+00,   1.89727331e+00,   5.62332731e-01,
#           4.16133814e-01,   1.71675686e-01,   1.89373656e+00,
#           2.60972655e+00,   2.07821070e+00,   1.99395223e+00,
# ...

# %% [markdown]
# ---
# ### 01-02. Covariance
#
# * blah blah about covariance

# %%
model['covariance']
# Out:
# array([[ 0.13623842,  2.33809124,  4.07062282,  2.31568973,  2.33518802,
#          4.10317291,  4.20129048,  4.18060462,  3.41600058,  4.22134671,
#          3.05155064,  3.28924781,  4.17575552,  2.60526706,  2.38302838,
#          4.23089545],
#        [ 2.33809124,  0.17357438,  4.08680078,  2.36738884,  2.35169314,
#          4.18640645,  4.214868  ,  4.20242869,  3.65854316,  4.22134671,
#          3.13048895,  3.36188404,  4.17809474,  2.59667687,  2.36139957,
#          4.23331664],
#        [ 4.07062282,  4.08680078,  1.20041459,  4.06865269,  4.07077901,
#          3.45630613,  3.51036595,  3.38839847,  4.11015063,  4.22134671,
#          4.16651402,  4.21845272,  4.2002452 ,  4.09452885,  4.10574429,
#          4.22270074],
#        [ 2.31568973,  2.36738884,  4.06865269,  0.00563467,  2.11928484,
#          4.01627262,  4.20625883,  4.19785498,  3.20994453,  4.22134671,
#          2.98034571,  3.72979611,  4.17281313,  2.32254386,  2.23165126,
#          4.22994679],
# ...

# %% [markdown]
# ---
# ### 01-03. Euclidean Distance
#
# * blah blah about euclidean distance

# %%
model['euclidean_distance']
# Out:
# array([[ 0.        ,  0.72426899,  2.73530859,  0.70381753,  0.71325932,
#          2.56182335,  2.8624084 ,  2.8317923 ,  1.93119555,  2.81457954,
#          1.76226294,  1.95594799,  3.00341731,  1.41531798,  0.73711553,
#          2.82074431],
#        [ 0.72426899,  0.        ,  3.14107521,  1.10925984,  1.00705027,
#          2.9567674 ,  3.27239009,  3.23924965,  2.02369165,  3.25932907,
#          2.10430026,  1.8510692 ,  3.41589621,  1.79866397,  0.82094878,
#          3.26462279],
#        [ 2.73530859,  3.14107521,  0.        ,  2.57557392,  2.64869319,
#          0.90451044,  0.66711871,  0.43740179,  3.14679339,  1.21985579,
#          2.36306565,  3.40112319,  1.693602  ,  2.24000986,  2.81041677,
#          1.23440663],
#        [ 0.70381753,  1.10925984,  2.57557392,  0.        ,  0.17311889,
#          2.38289641,  2.70019632,  2.68139417,  1.9304308 ,  2.6232545 ,
#          1.65079448,  2.43238814,  2.82913727,  0.94213805,  0.63270149,
#          2.63009704],
# ...

# %% [markdown]
# ---
# ### 01-04. Manhattan Distance
#
# * blah blah about manhatan distance

# %%
model['manhattan_distance']
# Out:
# array([[ 0.        ,  0.62813394,  2.28587098,  0.63598591,  0.67808187,
#          1.96595515,  2.3964241 ,  2.33516666,  1.93294241,  2.52604404,
#          1.68055995,  1.97464544,  2.46858757,  1.14680491,  0.71730003,
#          2.53350639],
#        [ 0.62813394,  0.        ,  2.90617939,  1.11262468,  1.02441598,
#          2.57575734,  3.00849382,  2.95843794,  2.02480627,  3.15417798,
#          2.1577985 ,  1.6748546 ,  3.09635233,  1.68037724,  0.80760768,
#          3.16159639],
#        [ 2.28587098,  2.90617939,  0.        ,  1.99187554,  2.11608096,
#          0.65694892,  0.28708283,  0.24174809,  2.9075141 ,  0.37682774,
#          1.56458925,  3.15543917,  0.37382475,  1.42813224,  2.37833591,
#          0.38449868],
#        [ 0.63598591,  1.11262468,  1.99187554,  0.        ,  0.12677714,
#          1.74655193,  2.07467374,  2.01733623,  1.78582922,  2.1861116 ,
#          1.55729655,  2.46614293,  2.14141395,  0.78482086,  0.53701634,
#          2.19383296],
# ...

# %% [markdown]
# ---
# ### 01-05. Gradient Similarity
#
# * blah blah about gradient similarity

# %%
model['gradient_similarity']
# Out:
# array([[ 0.        ,  0.11366711,  2.04185619,  0.25102075,  0.28032034,
#          2.75495537,  2.10285036,  1.85067596,  0.40013454,  0.31756543,
#          0.43765451,  0.5145914 ,  1.5969794 ,  0.29651003,  0.32316426,
#          0.44384714],
#        [ 0.11366711,  0.        ,  2.10210924,  0.29260353,  0.28371429,
#          2.82556488,  2.18237017,  1.92806682,  0.42041499,  0.33822413,
#          0.43943182,  0.46242326,  1.6070813 ,  0.31052392,  0.3151906 ,
#          0.46446532],
#        [ 2.04185619,  2.10210924,  0.        ,  2.08500487,  2.11120838,
#          2.14705624,  1.93961579,  1.41308755,  2.0488974 ,  1.97853882,
#          2.20748893,  2.44318474,  3.19076547,  2.01326707,  2.17376158,
#          2.10490345],
#        [ 0.25102075,  0.29260353,  2.08500487,  0.        ,  0.0426564 ,
#          2.70404855,  2.08657756,  1.83600793,  0.31371386,  0.23105844,
#          0.39423812,  0.52450469,  1.52912527,  0.23613521,  0.30530966,
#          0.35716135],
# ...

# %% [markdown]
# ---
# ### 01-06. Reversed-Gradient Similarity
#
# * blah blah about reversed gradient similarity

# %%
model['reversed_gradient_similarity']
# Out:
# array([[ 0.56736257,  0.58581699,  1.90641063,  0.49008585,  0.49613083,
#          2.50196203,  1.94850145,  1.72240726,  0.35819341,  0.28368128,
#          0.6268882 ,  0.860105  ,  1.44891554,  0.39830525,  0.58173973,
#          0.39596277],
#        [ 0.58581699,  0.60427142,  1.93135996,  0.50854028,  0.51458525,
#          2.51764149,  1.97334201,  1.74891215,  0.37664784,  0.30213571,
#          0.64534263,  0.87855943,  1.45786595,  0.41675968,  0.60008069,
#          0.41415874],
#        [ 1.90641063,  1.93135996,  3.53485856,  1.87837972,  1.88709488,
#          3.78704769,  3.39722151,  3.16258899,  1.84194141,  1.76742928,
#          1.95121894,  2.14861642,  2.82993439,  1.78867854,  1.93279573,
#          1.86829795],
#        [ 0.49008585,  0.50854028,  1.87837972,  0.41280913,  0.41885411,
#          2.44438145,  1.88964248,  1.6638799 ,  0.28091669,  0.20640457,
#          0.54588702,  0.77910382,  1.38280468,  0.32241852,  0.50574019,
#          0.31900489],
# ...

# %%
path
# Out:
# '/Users/JH/Documents/GitHub/EnergyData_jhyun/repository/1440/fully_refined/similarity_model/similarity.bin'

# %% [markdown]
# ---
# # 02. A Command line for Build Similarity Model

# %%
Similarity.Build.similarity_model(time_interval=GlobalParameter.TimeInterval, 
                                  refined_type=GlobalParameter.FullyPreprocessedPath)
# Out:
# Build Similarity Model
# calculate covariance
# calculate cosine_similarity
# calculate euclidean_distance
# calculate manhattan_distance
# calculate gradient_similarity
# calculate reversed_gradient_similarity
# ({'cosine_similarity': array([[  1.20011145e-06,   4.64656165e-02,   1.87699950e+00,
#             8.11008196e-02,   8.51220035e-02,   1.50251707e+00,
#             2.20486843e+00,   2.09883902e+00,   5.03661729e-01,
#             2.60972655e+00,   5.73118707e-01,   4.52012166e-01,
#             2.46423454e+00,   3.41036546e-01,   8.70315493e-02,
#             2.60633105e+00],
#          [  4.64656165e-02,   2.84370155e-05,   1.87296738e+00,
#             1.26049931e-01,   1.04897210e-01,   1.50981159e+00,
#             2.19333523e+00,   2.09156566e+00,   5.03740055e-01,
#             2.60972655e+00,   6.09692822e-01,   3.89283912e-01,
#             2.46647182e+00,   3.81530102e-01,   7.32197615e-02,
#             2.60636356e+00],
# ...
